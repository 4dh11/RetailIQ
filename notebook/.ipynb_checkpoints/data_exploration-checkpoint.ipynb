# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("/home/adityaa/Desktop/Mini Project/data/online_retail_09_10.csv")
df2 = pd.read_csv("/home/adityaa/Desktop/Mini Project/data/online_retail_10_11.csv")

# %%
df1.shape
# Out:
# (525461, 8)

# %%
df2.shape
# Out:
# (541910, 8)

# %%
df1.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='str')

# %%
df2.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='str')

# %%
df = pd.concat([df1, df2], ignore_index=True)
df.shape
# Out:
# (1067371, 8)

# %%
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])

df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1    489434    79323P                   PINK CHERRY LIGHTS        12
# 2    489434    79323W                  WHITE CHERRY LIGHTS        12
# 3    489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4    489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2009-12-01 07:45:00       6.95     13085.0  United Kingdom
# 1 2009-12-01 07:45:00       6.75     13085.0  United Kingdom
# 2 2009-12-01 07:45:00       6.75     13085.0  United Kingdom
# 3 2009-12-01 07:45:00       2.10     13085.0  United Kingdom
# 4 2009-12-01 07:45:00       1.25     13085.0  United Kingdom

# %%
df["Sales"] = df["Quantity"] * df["UnitPrice"]
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1    489434    79323P                   PINK CHERRY LIGHTS        12
# 2    489434    79323W                  WHITE CHERRY LIGHTS        12
# 3    489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4    489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Sales
# 0 2009-12-01 07:45:00       6.95     13085.0  United Kingdom   83.4
# 1 2009-12-01 07:45:00       6.75     13085.0  United Kingdom   81.0
# 2 2009-12-01 07:45:00       6.75     13085.0  United Kingdom   81.0
# 3 2009-12-01 07:45:00       2.10     13085.0  United Kingdom  100.8
# 4 2009-12-01 07:45:00       1.25     13085.0  United Kingdom   30.0

# %%
#Data Cleaning

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     243007
# Country             0
# Sales               0
# dtype: int64

# %%
# Removing rows with missing CustomerID
df = df.dropna(subset=['CustomerID'])

df['CustomerID'] = df['CustomerID'].astype(int)

print(df.shape)
# Out:
# (824364, 9)

# %%
# Removing cancelled invoices
df = df[~df['InvoiceNo'].astype(str).str.startswith('C')]

print(df.shape)
# Out:
# (805620, 9)

# %%
# Removing negative or zero values
df = df[(df['Quantity'] > 0) & (df['UnitPrice'] > 0)]

print(df.shape)
# Out:
# (805549, 9)

# %%
df["Year"] = df["InvoiceDate"].dt.year
df["Month"] = df["InvoiceDate"].dt.month
df["Day"] = df["InvoiceDate"].dt.day
df["Hour"] = df["InvoiceDate"].dt.hour

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 805549 entries, 0 to 1067370
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    805549 non-null  str
#  1   StockCode    805549 non-null  str
#  2   Description  805549 non-null  str
#  3   Quantity     805549 non-null  int64
#  4   InvoiceDate  805549 non-null  datetime64[us]
#  5   UnitPrice    805549 non-null  float64
#  6   CustomerID   805549 non-null  int64
#  7   Country      805549 non-null  str
#  8   Sales        805549 non-null  float64
#  9   Year         805549 non-null  int32
#  10  Month        805549 non-null  int32
#  11  Day          805549 non-null  int32
#  12  Hour         805549 non-null  int32
# dtypes: datetime64[us](1), float64(2), int32(4), int64(2), str(4)
# memory usage: 73.8 MB

# %%
df.describe()
# Out:
#             Quantity                 InvoiceDate      UnitPrice  \
# count  805549.000000                      805549  805549.000000
# mean       13.290522  2011-01-02 10:24:44.106814       3.206561
# min         1.000000         2009-12-01 07:45:00       0.001000
# 25%         2.000000         2010-07-07 12:08:00       1.250000
# 50%         5.000000         2010-12-03 15:10:00       1.950000
# 75%        12.000000         2011-07-28 13:05:00       3.750000
# max     80995.000000         2011-12-09 12:50:00   10953.500000
# std       143.634088                         NaN      29.199173
#
#           CustomerID          Sales           Year          Month  \
# count  805549.000000  805549.000000  805549.000000  805549.000000
# mean    15331.954970      22.026505    2010.423282       7.507281
# min     12346.000000       0.001000    2009.000000       1.000000
# 25%     13982.000000       4.950000    2010.000000       5.000000
# ...

# %%
monthly_sales = df.groupby(["Year","Month"])["Sales"].sum().reset_index()

monthly_sales.head()
# Out:
#    Year  Month       Sales
# 0  2009     12  686654.160
# 1  2010      1  557319.062
# 2  2010      2  506371.066
# 3  2010      3  699608.991
# 4  2010      4  594609.192

# %%
plt.figure(figsize=(10,5))

plt.plot(monthly_sales["Sales"])

plt.title("Monthly Sales Trend")
plt.xlabel("Month Index")
plt.ylabel("Total Sales")

plt.show()

# %%
top_products = df.groupby("Description")["Quantity"].sum().sort_values(ascending=False).head(10)

top_products.plot(kind="bar", figsize=(10,5))

plt.title("Top 10 Selling Products")

plt.show()

# %%
country_sales = df.groupby("Country")["Sales"].sum().sort_values(ascending=False).head(10)

country_sales.plot(kind="bar", figsize=(10,5))

plt.title("Top 10 Countries by Sales")
plt.xlabel("Country")
plt.ylabel("Total Sales")
plt.show()

# %%
product_demand = df.groupby("StockCode")["Quantity"].sum().reset_index()

product_demand = product_demand.sort_values(by="Quantity", ascending=False)

product_demand.head(10)
# Out:
#      StockCode  Quantity
# 3410     84077    109169
# 4058    85099B     94983
# 4080    85123A     93697
# 601      21212     91263
# 2726     23843     80995
# 3819     84879     79913
# 1405     22197     77971
# 2324     23166     77916
# 108      17003     71129
# 1219     21977     55270

# %%
snapshot_date = df['InvoiceDate'].max() + pd.Timedelta(days=1)

rfm = df.groupby('CustomerID').agg({
    'InvoiceDate': lambda x: (snapshot_date - x.max()).days,
    'InvoiceNo': 'nunique',
    'Sales': 'sum'
})

rfm.columns = ['Recency', 'Frequency', 'Monetary']

rfm.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346           326         12  77556.46
# 12347             2          8   5633.32
# 12348            75          5   2019.40
# 12349            19          4   4428.69
# 12350           310          1    334.40

# %%
rfm.shape
# Out:
# (5878, 3)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

rfm_scaled = scaler.fit_transform(rfm)

rfm_scaled = pd.DataFrame(rfm_scaled, columns=rfm.columns)

rfm_scaled.head()
# Out:
#     Recency  Frequency  Monetary
# 0  0.595584   0.438998  5.058050
# 1 -0.952279   0.131502  0.177431
# 2 -0.603532  -0.099120 -0.067806
# 3 -0.871064  -0.175994  0.095686
# 4  0.519146  -0.406616 -0.182148

# %%
from sklearn.cluster import KMeans

inertia = []

for k in range(1,10):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(rfm_scaled)
    inertia.append(kmeans.inertia_)

plt.plot(range(1,10), inertia)

plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia")

plt.show()

# %%
kmeans = KMeans(n_clusters=4, random_state=42)

rfm["Cluster"] = kmeans.fit_predict(rfm_scaled)

rfm.head()
# Out:
#             Recency  Frequency  Monetary  Cluster
# CustomerID
# 12346           326         12  77556.46        1
# 12347             2          8   5633.32        1
# 12348            75          5   2019.40        1
# 12349            19          4   4428.69        1
# 12350           310          1    334.40        0

# %%
rfm.groupby("Cluster").mean()
# Out:
#             Recency   Frequency       Monetary
# Cluster
# 0        463.032032    2.212212     765.244446
# 1         67.005728    7.307732    3009.402451
# 2         25.942857  103.714286   83086.079771
# 3          3.500000  212.500000  436835.792500

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    x=rfm["Recency"],
    y=rfm["Monetary"],
    hue=rfm["Cluster"],
    palette="Set1"
)

plt.title("Customer Segmentation")

plt.show()

# %%
df.to_csv("../data/processed_retail_data.csv", index=False)

# %%
# Save cleaned transaction-level data (already in your notebook)
df.to_csv("../data/processed_retail_data.csv", index=False)
print(f"Saved processed_retail_data.csv — {df.shape[0]} rows")

# %%
# Save RFM with cluster labels — needed for churn model
# rfm already has Recency, Frequency, Monetary from your notebook
# rfm["Cluster"] was assigned during KMeans — we need to reset index to get CustomerID back

snapshot_date = df["InvoiceDate"].max() + pd.Timedelta(days=1)

rfm_export = df.groupby("CustomerID").agg(
    Recency   = ("InvoiceDate", lambda x: (snapshot_date - x.max()).days),
    Frequency = ("InvoiceNo",   "nunique"),
    Monetary  = ("Sales",       "sum")
).reset_index()

# Re-attach cluster labels using the same scaler + model you already fitted
rfm_export["Cluster"] = rfm["Cluster"].values

rfm_export.to_csv("../data/rfm_segments.csv", index=False)
print(f"Saved rfm_segments.csv — {rfm_export.shape[0]} customers")
rfm_export.head()
